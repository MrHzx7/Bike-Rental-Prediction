# %%
#Banking
#Course-end Project 2

# %%
import pandas as pd

# Specifying the file paths
data_file_path = r"C:\Users\haris\Desktop\Banking\Dataset\data.xlsx"
dictionary_file_path = r"C:\Users\haris\Desktop\Banking\Dataset\Data Dictionary.xlsx"

# Loading the data files into pandas DataFrames
data_df = pd.read_excel(data_file_path)
dictionary_df = pd.read_excel(dictionary_file_path)

# Displaying the first few rows of each DataFrame to confirm they are loaded correctly
print("Data Preview:")
print(data_df.head())

print("\nData Dictionary Preview:")
print(dictionary_df.head())
# Out:
# Data Preview:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441    1984-01-01        Salaried  ...
# 1               45                1497    1985-08-24   Self employed  ...
# 2               45                1495    1977-12-09   Self employed  ...
# 3               45                1502    1988-06-01        Salaried  ...
# 4               86                1499    1994-07-14   Self employed  ...
#
# ...

# %%
# Display the first few rows
print(data_df.head())

# Summary of the dataset
print(data_df.info())

# Check for missing values
missing_values = data_df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Check for duplicate rows
duplicates = data_df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441    1984-01-01        Salaried  ...
# 1               45                1497    1985-08-24   Self employed  ...
# 2               45                1495    1977-12-09   Self employed  ...
# 3               45                1502    1988-06-01        Salaried  ...
# 4               86                1499    1994-07-14   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
# Fill missing numerical values with the median
numerical_columns = data_df.select_dtypes(include=['float64', 'int64']).columns
data_df[numerical_columns] = data_df[numerical_columns].apply(lambda x: x.fillna(x.median()))

# Fill missing categorical values with "Unknown"
categorical_columns = data_df.select_dtypes(include=['object']).columns
data_df[categorical_columns] = data_df[categorical_columns].apply(lambda x: x.fillna("Unknown"))
print("Missing values after handling:")
print(data_df.isnull().sum())
# Out:
# Missing values after handling:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Date.of.Birth                          0
# Employment.Type                        0
# DisbursalDate                          0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# ...

# %%
# Rename columns to align with Python conventions
data_df.columns = data_df.columns.str.lower().str.replace('.', '_').str.replace(' ', '_')

# %%
import datetime

# Calculate age
current_year = datetime.datetime.now().year
data_df['age'] = current_year - pd.to_datetime(data_df['date_of_birth']).dt.year

# %%
#Exploratory Data Analysis (EDA)

# %%
#Statistical Description of Quantitative Data Variables
# The statistical summary
quantitative_columns = ['disbursed_amount', 'asset_cost', 'ltv', 'PERFORM_CNS.SCORE', 
                        'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 
                        'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT', 
                        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS', 
                        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 
                        'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 
                        'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT', 
                        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 
                        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']

# Statistical description
print(data[quantitative_columns].describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 14
#       3 quantitative_columns = ['disbursed_amount', 'asset_cost', 'ltv', 'PERFORM_CNS.SCORE',
#       4                         'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS',
#       5                         'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#    (...)
#      10                         'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#      11                         'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']
#      13 # Statistical description
# ---> 14 print(data[quantitative_columns].describe())
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# Specify the file path
file_path = r'C:\Users\haris\Desktop\Banking\Dataset\data.xlsx'
dictionary_path = r'C:\Users\haris\Desktop\Banking\Dataset\Data Dictionary.xlsx'

# Load the datasets
data = pd.read_excel(file_path)
data_dictionary = pd.read_excel(dictionary_path)

# %%
# Provide the statistical summary
quantitative_columns = ['disbursed_amount', 'asset_cost', 'ltv', 'PERFORM_CNS.SCORE', 
                        'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 
                        'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT', 
                        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS', 
                        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 
                        'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 
                        'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT', 
                        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 
                        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']

# Statistical description
print(data[quantitative_columns].describe())
# Out:
#        disbursed_amount    asset_cost            ltv  PERFORM_CNS.SCORE  \
# count     233154.000000  2.331540e+05  233154.000000      233154.000000
# mean       54356.993528  7.586507e+04      74.746530         289.462994
# std        12971.314171  1.894478e+04      11.456636         338.374779
# min        13320.000000  3.700000e+04      10.030000           0.000000
# 25%        47145.000000  6.571700e+04      68.880000           0.000000
# 50%        53803.000000  7.094600e+04      76.800000           0.000000
# 75%        60413.000000  7.920175e+04      83.670000         678.000000
# max       990572.000000  1.628992e+06      95.000000         890.000000
#
#        PRI.NO.OF.ACCTS  PRI.ACTIVE.ACCTS  PRI.OVERDUE.ACCTS  \
# count    233154.000000     233154.000000      233154.000000
# mean          2.440636          1.039896           0.156549
# std           5.217233          1.941496           0.548787
# min           0.000000          0.000000           0.000000
# ...

# %%
#Target Variable Distribution
# Distribution of the target variable
sns.countplot(data=data, x='loan_default', palette='viridis')
plt.title('Distribution of Target Variable (Loan Default)')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 #Target Variable Distribution
#       2 # Distribution of the target variable
# ----> 3 sns.countplot(data=data, x='loan_default', palette='viridis')
#       4 plt.title('Distribution of Target Variable (Loan Default)')
#       5 plt.xlabel('Loan Default (0 = No, 1 = Yes)')
#
# NameError: name 'sns' is not defined

# %%
#Target Variable Distribution
# Distribution of the target variable
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of the target variable
sns.countplot(data=data, x='loan_default', palette='viridis')
plt.title('Distribution of Target Variable (Loan Default)')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\haris\AppData\Local\Temp\ipykernel_5640\666407859.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='loan_default', palette='viridis')

# %%
#Distribution of Target Variable Across Categories
# Branch-wise distribution
branch_dist = data.groupby('branch_id')['loan_default'].value_counts(normalize=True).unstack()
branch_dist.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Branch-wise Default Distribution')
plt.xlabel('Branch ID')
plt.ylabel('Proportion')
plt.legend(['Non-Default', 'Default'])
plt.show()

# Similarly, repeat for city, state, supplier, and manufacturer
# Example for supplier
supplier_dist = data.groupby('supplier_id')['loan_default'].value_counts(normalize=True).unstack()
supplier_dist.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Supplier-wise Default Distribution')
plt.xlabel('Supplier ID')
plt.ylabel('Proportion')
plt.legend(['Non-Default', 'Default'])
plt.show()

# %%
#Employment Types and Strategies for Missing Values
# Employment Type Distribution
employment_counts = data['Employment.Type'].value_counts(dropna=False)

# Pie Chart for Employment Types
employment_counts.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), labels=employment_counts.index, startangle=90)
plt.title('Employment Type Distribution')
plt.ylabel('')
plt.show()

# Distribution of Employment Type by Default Status
sns.countplot(data=data, x='Employment.Type', hue='loan_default', palette='Set2')
plt.title('Employment Type vs Loan Default')
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Strategy for Missing Values:
# Replace missing values in Employment.Type with the mode (most common value)
data['Employment.Type'].fillna(data['Employment.Type'].mode()[0], inplace=True)
# Out:
# C:\Users\haris\AppData\Local\Temp\ipykernel_5640\270652095.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Employment.Type'].fillna(data['Employment.Type'].mode()[0], inplace=True)

# %%
#Age and Loan Default Analysis

# %%
# Convert Date of Birth to Age
from datetime import datetime

data['age'] = data['Date.of.Birth'].apply(lambda x: datetime.now().year - pd.to_datetime(x).year)

# Age Distribution for Defaulters and Non-Defaulters
sns.histplot(data=data, x='age', hue='loan_default', kde=True, bins=30, palette='coolwarm')
plt.title('Age Distribution by Loan Default')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
#ID Proofs Used by Customers
# Calculate the count of each ID type
id_proofs = ['Aadhar_flag', 'PAN_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag']
id_counts = data[id_proofs].sum()

# Bar plot for ID Proofs
id_counts.plot(kind='bar', color='skyblue', figsize=(8, 5))
plt.title('ID Proofs Used by Customers')
plt.xlabel('ID Proof Type')
plt.ylabel('Count')
plt.show()

# %%
# Correlation Heatmap
correlation_columns = ['loan_default', 'PRI.NO.OF.ACCTS', 'ltv', 'PERFORM_CNS.SCORE', 
                       'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']
sns.heatmap(data[correlation_columns].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       1 # Correlation Heatmap
#       2 correlation_columns = ['loan_default', 'PRI.NO.OF.ACCTS', 'ltv', 'PERFORM_CNS.SCORE',
#       3                        'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']
# ----> 4 sns.heatmap(data[correlation_columns].corr(), annot=True, cmap='coolwarm')
#       5 plt.title('Correlation Heatmap')
#       6 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...

# %%
# Preprocessing CREDIT.HISTORY.LENGTH
def convert_to_months(value):
    """Convert 'Xyrs Ymon' to total months as integer."""
    try:
        years, months = value.split('yrs')[0], value.split('yrs')[1].split('mon')[0]
        return int(years.strip()) * 12 + int(months.strip())
    except:
        return None

# Apply conversion to the column
data['CREDIT.HISTORY.LENGTH'] = data['CREDIT.HISTORY.LENGTH'].apply(convert_to_months)

# Drop rows with NaN after conversion (if any)
data.dropna(subset=['CREDIT.HISTORY.LENGTH'], inplace=True)

# Correlation Heatmap
correlation_columns = ['loan_default', 'PRI.NO.OF.ACCTS', 'ltv', 'PERFORM_CNS.SCORE', 
                       'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES']
sns.heatmap(data[correlation_columns].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Calculate the total number of occurrences for each ID flag
id_usage = data[['Aadhar_flag', 'PAN_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag']].sum()

# Find the most commonly used ID proof
most_common_id = id_usage.idxmax()
most_common_id_count = id_usage.max()

print("Most commonly used ID proof:", most_common_id)
print("Number of customers using this ID proof:", most_common_id_count)
# Out:
# Most commonly used ID proof: Aadhar_flag
# Number of customers using this ID proof: 195924

# %%
#Analyze Credit Bureau Score Distribution
sns.histplot(data=data, x='PERFORM_CNS.SCORE', hue='PERFORM_CNS.SCORE.DESCRIPTION', kde=True, bins=30)
plt.title('Credit Bureau Score Distribution')
plt.show()

# %%
#Explore Primary and Secondary Account Details
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the differences for primary and secondary loans
data['Primary_Loan_Difference'] = data['PRI.SANCTIONED.AMOUNT'] - data['PRI.DISBURSED.AMOUNT']
data['Secondary_Loan_Difference'] = data['SEC.SANCTIONED.AMOUNT'] - data['SEC.DISBURSED.AMOUNT']

# Plot the distributions of differences
sns.histplot(data=data, x='Primary_Loan_Difference', kde=True, color='blue', bins=30)
plt.title('Distribution of Primary Loan Difference')
plt.xlabel('Primary Loan Difference (Sanctioned - Disbursed)')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data=data, x='Secondary_Loan_Difference', kde=True, color='green', bins=30)
plt.title('Distribution of Secondary Loan Difference')
plt.xlabel('Secondary Loan Difference (Sanctioned - Disbursed)')
plt.ylabel('Frequency')
plt.show()

# %%
#Sanctioned vs Disbursed Loan Amounts

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplot for Primary Overdue Accounts vs Default Status
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='loan_default', y='PRI.OVERDUE.ACCTS', palette='Set2')
plt.title('Primary Overdue Accounts vs Loan Default')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Number of Overdue Primary Accounts')
plt.show()

# Boxplot for Secondary Overdue Accounts vs Default Status
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='loan_default', y='SEC.OVERDUE.ACCTS', palette='Set3')
plt.title('Secondary Overdue Accounts vs Loan Default')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Number of Overdue Secondary Accounts')
plt.show()

# Comparison of Sanctioned and Disbursed Amounts for Primary Loans
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='PRI.SANCTIONED.AMOUNT', y='PRI.DISBURSED.AMOUNT', hue='loan_default', alpha=0.7)
plt.title('Primary Sanctioned vs Disbursed Amounts')
plt.xlabel('Primary Sanctioned Amount')
plt.ylabel('Primary Disbursed Amount')
plt.legend(title='Loan Default', loc='best')
plt.show()

# Comparison of Sanctioned and Disbursed Amounts for Secondary Loans
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='SEC.SANCTIONED.AMOUNT', y='SEC.DISBURSED.AMOUNT', hue='loan_default', alpha=0.7)
plt.title('Secondary Sanctioned vs Disbursed Amounts')
plt.xlabel('Secondary Sanctioned Amount')
plt.ylabel('Secondary Disbursed Amount')
plt.legend(title='Loan Default', loc='best')
plt.show()

# Analyzing the differences
primary_diff = data['PRI.SANCTIONED.AMOUNT'] - data['PRI.DISBURSED.AMOUNT']
secondary_diff = data['SEC.SANCTIONED.AMOUNT'] - data['SEC.DISBURSED.AMOUNT']

plt.figure(figsize=(10, 6))
sns.histplot(primary_diff, kde=True, bins=30, color='blue', label='Primary Difference')
sns.histplot(secondary_diff, kde=True, bins=30, color='green', label='Secondary Difference')
plt.title('Differences Between Sanctioned and Disbursed Amounts')
plt.xlabel('Sanctioned - Disbursed Amount')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# C:\Users\haris\AppData\Local\Temp\ipykernel_5640\1722158122.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='loan_default', y='PRI.OVERDUE.ACCTS', palette='Set2')
# C:\Users\haris\AppData\Local\Temp\ipykernel_5640\1722158122.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='loan_default', y='SEC.OVERDUE.ACCTS', palette='Set3')

# %%
#Sanctioned vs. Disbursed Loan Amounts
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the differences for primary and secondary loans
data['Primary_Loan_Difference'] = data['PRI.SANCTIONED.AMOUNT'] - data['PRI.DISBURSED.AMOUNT']
data['Secondary_Loan_Difference'] = data['SEC.SANCTIONED.AMOUNT'] - data['SEC.DISBURSED.AMOUNT']

# Plot the distributions of differences
sns.histplot(data=data, x='Primary_Loan_Difference', kde=True, color='blue', bins=30)
plt.title('Distribution of Primary Loan Difference')
plt.xlabel('Primary Loan Difference (Sanctioned - Disbursed)')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data=data, x='Secondary_Loan_Difference', kde=True, color='green', bins=30)
plt.title('Distribution of Secondary Loan Difference')
plt.xlabel('Secondary Loan Difference (Sanctioned - Disbursed)')
plt.ylabel('Frequency')
plt.show()

# %%
#Number of Inquiries and Default Probability
# Boxplot to analyze relationship
sns.boxplot(data=data, x='loan_default', y='NO.OF_INQUIRIES')
plt.title('Number of Inquiries vs Loan Default')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Number of Inquiries')
plt.show()

# %%
#Credit History Analysis
# Analyze the impact of NEW.ACCTS.IN.LAST.SIX.MONTHS on loan default
sns.boxplot(data=data, x='loan_default', y='NEW.ACCTS.IN.LAST.SIX.MONTHS')
plt.title('New Accounts in Last 6 Months vs Loan Default')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('New Accounts in Last 6 Months')
plt.show()

# Analyze the impact of DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS on loan default
sns.boxplot(data=data, x='loan_default', y='DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS')
plt.title('Delinquent Accounts in Last 6 Months vs Loan Default')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Delinquent Accounts in Last 6 Months')
plt.show()

# Analyze the impact of CREDIT.HISTORY.LENGTH on loan default
sns.boxplot(data=data, x='loan_default', y='CREDIT.HISTORY.LENGTH')
plt.title('Credit History Length vs Loan Default')
plt.xlabel('Loan Default (0 = No, 1 = Yes)')
plt.ylabel('Credit History Length')
plt.show()

# %%
#Logistic Regression Modeling
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# Select features and target
X = data[['PERFORM_CNS.SCORE', 'NO.OF_INQUIRIES', 'NEW.ACCTS.IN.LAST.SIX.MONTHS', 
          'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'Primary_Loan_Difference', 'Secondary_Loan_Difference']]
y = data['loan_default']

# Handle missing values
X = X.fillna(X.mean())

# Scale the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Logistic regression model with increased max_iter
model = LogisticRegression(max_iter=500)
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[54996    56]
#  [14867    28]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88     55052
#            1       0.33      0.00      0.00     14895
#
#     accuracy                           0.79     69947
#    macro avg       0.56      0.50      0.44     69947
# weighted avg       0.69      0.79      0.69     69947

# %%
#ROC Curve and AUC

# %%
# Predict probabilities for ROC
y_pred_prob = model.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'r--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()
